# %%
import pandas as pd
import numpy as np
import datetime
from os import listdir
from pylab import plt
plt.style.use('seaborn')
import matplotlib as mpl
mpl.rcParams['font.family'] = 'serif'
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("properatti.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'operation', 'property_type', 'place_name',
#        'place_with_parent_names', 'country_name', 'state_name', 'geonames_id',
#        'lat-lon', 'lat', 'lon', 'price', 'currency',
#        'price_aprox_local_currency', 'price_aprox_usd', 'surface_total_in_m2',
#        'surface_covered_in_m2', 'price_usd_per_m2', 'price_per_m2', 'floor',
#        'rooms', 'expenses', 'properati_url', 'description', 'title',
#        'image_thumbnail'],
#       dtype='object')

# %%
dolar=18

# %%
df.rename(columns={'Unnamed: 0':'ID'}, inplace=True)

# %%
df.drop(df.columns[[1,4,7,8,22,25]], axis=1, inplace=True)

# %%
import re

# %%
#df_apartments = df[(df["property_type"]=="apartment")]

# %%
#df_cf = df[(df["state_name"]=="Capital Federal")]
df_apartments = df[(df["property_type"]=="apartment") & (df["state_name"]=="Capital Federal")]
df_apartments
# Out:
#             ID property_type         place_name country_name       state_name  \
# 2            2     apartment          Mataderos    Argentina  Capital Federal
# 7            7     apartment           Belgrano    Argentina  Capital Federal
# 8            8     apartment           Belgrano    Argentina  Capital Federal
# 13          13     apartment       Palermo Soho    Argentina  Capital Federal
# 14          14     apartment       Palermo Soho    Argentina  Capital Federal
# 19          19     apartment            Palermo    Argentina  Capital Federal
# 21          21     apartment            Palermo    Argentina  Capital Federal
# 29          29     apartment             Flores    Argentina  Capital Federal
# 35          35     apartment              Boedo    Argentina  Capital Federal
# 38          38     apartment        Las Cañitas    Argentina  Capital Federal
# 48          48     apartment          Balvanera    Argentina  Capital Federal
# ...

# %%
df_apartments.to_csv('apartments.csv')

# %%
pattern = '([0-9])+\s+dorm'
df_apartments["ambientes"]=df_apartments[df_apartments["ambientes"].isnull()]["title"].str.extract(pattern,flags=re.IGNORECASE,expand=TRUE)
df_apartments
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ambientes'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-070a4223a27f> in <module>()
#       1 pattern = '([0-9])+\s+dorm'
# ...

# %%
import re
pattern = '([0-9])+\s+amb'
amb_title = df_apartments["title"].str.extract(pattern,flags=re.IGNORECASE,expand=False)

# %%
amb_descr = df_apartments["description"].str.extract(pattern,flags=re.IGNORECASE,expand=False)

# %%
df_rooms_full = pd.DataFrame({'orig':df_apartments["rooms"],
                             'description':amb_descr,
                             'title':amb_title
                             })

# %%
import numpy as np

# %%
def guardarDescripcion(x):
    if not x['title'] is np.nan:
        return x['title']
    if not x['description'] is np.nan:
        return x['description']
    return x['orig']

# %%
ambientes_mejorado = df_rooms_full.apply(guardarDescripcion,axis=1)

# %%
df_apartments.groupby('place_name')
for i in df_apartments.groupby('place_name'):
    print(i)
# Out:
# ('Abasto',             ID property_type place_name country_name       state_name  \
# 791        791     apartment     Abasto    Argentina  Capital Federal
# 5356      5356     apartment     Abasto    Argentina  Capital Federal
# 5395      5395     apartment     Abasto    Argentina  Capital Federal
# 5493      5493     apartment     Abasto    Argentina  Capital Federal
# 12842    12842     apartment     Abasto    Argentina  Capital Federal
# 17996    17996     apartment     Abasto    Argentina  Capital Federal
# 19603    19603     apartment     Abasto    Argentina  Capital Federal
# 19604    19604     apartment     Abasto    Argentina  Capital Federal
# 20373    20373     apartment     Abasto    Argentina  Capital Federal
# 20634    20634     apartment     Abasto    Argentina  Capital Federal
# 20635    20635     apartment     Abasto    Argentina  Capital Federal
# 23523    23523     apartment     Abasto    Argentina  Capital Federal
# ...

# %%
df_apartments.groupby('place_name').describe()
# Out:
#                           ID                                                 \
#                        count          mean           std      min       25%
# place_name
# Abasto                  79.0  59879.784810  29760.509894    791.0  40663.50
# Agronomía               29.0  52550.896552  27844.505170    382.0  40073.00
# Almagro               1023.0  58084.349951  32543.952152     98.0  31215.00
# Balvanera              584.0  59871.705479  35137.468606     48.0  31148.25
# Barracas               324.0  50330.858025  37173.142011    341.0  16859.25
# Barrio Norte          1063.0  57273.735654  34377.037834    178.0  28681.00
# Belgrano              2761.0  70824.260775  33264.248473      7.0  47642.00
# Boca                   178.0  64203.073034  33549.846781    496.0  30396.25
# Boedo                  793.0  34603.268600  23244.947886     35.0  25715.00
# Caballito             2079.0  61620.537278  32960.910097     52.0  36674.00
# ...

# %%
pattern = '([0-9])+\s+AMB'

# %%
type(df_apartments)
# Out:
# pandas.core.frame.DataFrame

# %%
df_apartments["ambientes"] = df_apartments["description"].str.extract(pattern,flags=re.IGNORECASE)
# Out:
# C:\Users\Ale Stringhini\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_apartments.ambientes.unique()
# Out:
# array(['2', nan, '3', '4', '1', '5', '6', '8', '7', '0', '9'],
#       dtype=object)

# %%
df_apartments["ambientes"]=df_apartments[df_apartments["ambientes"].isnull()]["title"].str.extract(pattern,flags=re.IGNORECASE)
# Out:
# C:\Users\Ale Stringhini\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
pattern = '([0-9])+\s+dorm'
#df_apartments["ambientes"]=df_apartments[df_apartments["ambientes"].isnull()]["title"].str.extract(pattern,flags=re.IGNORECASE)
df_apartments
# Out:
#             ID property_type         place_name country_name       state_name  \
# 2            2     apartment          Mataderos    Argentina  Capital Federal
# 7            7     apartment           Belgrano    Argentina  Capital Federal
# 8            8     apartment           Belgrano    Argentina  Capital Federal
# 13          13     apartment       Palermo Soho    Argentina  Capital Federal
# 14          14     apartment       Palermo Soho    Argentina  Capital Federal
# 19          19     apartment            Palermo    Argentina  Capital Federal
# 21          21     apartment            Palermo    Argentina  Capital Federal
# 29          29     apartment             Flores    Argentina  Capital Federal
# 35          35     apartment              Boedo    Argentina  Capital Federal
# 38          38     apartment        Las Cañitas    Argentina  Capital Federal
# 48          48     apartment          Balvanera    Argentina  Capital Federal
# ...
